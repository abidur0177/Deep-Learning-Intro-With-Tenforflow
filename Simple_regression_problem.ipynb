# %% [markdown]
# <a href="https://colab.research.google.com/github/abidur0177/Deep-Learning-With-Tenforflow/blob/main/Intro_Tenforflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Build the model with only one layer and one input

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# ## Compile the model with optiizer and loss function

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Provide the data points

# %%
x = np.arange(-1.0,10.1,1).astype('f')
y = np.arange(-3.0,19.1,2).astype('f')

# %% [markdown]
# ## Fit the data to the model

# %%
model.fit(x,y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 662ms/step - loss: 186.8563
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 22.6748
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2456
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9392
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6583
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6171
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6045
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5953
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5866
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5781
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5697
# Epoch 12/500
# ...

# %% [markdown]
# ## Predict any value from the model

# %%
model.predict([11.0])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[20.980635]], dtype=float32)
